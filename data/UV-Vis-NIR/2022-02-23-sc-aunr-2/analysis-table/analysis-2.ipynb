# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-23-sc-aunr-2/analysis-table/iterations.csv')
df
# Out:
#     Iteration #  ascorbic acid [anish-making-sc-rods]  \
# 0             1                                   470
# 1             2                                   315
# 2             3                                   438
# 3             4                                   180
# 4             5                                   477
# 5             6                                   391
# 6             7                                   371
# 7             8                                   480
# 8             9                                   490
# 9            10                                   480
# 10           11                                   491
# 11           12                                   482
# 12           13                                   449
# 13           14                                   473
# 14           15                                   489
# 15           16                                   497
# 16           17                                   496
# 17           18                                   486
# 18           19                                   495
# 19           20                                   481
#
#     au seeds [anish-making-sc-rods]  hcl [anish-making-sc-rods]  \
# 0                                36                         943
# 1                                23                         997
# 2                                37                         878
# 3                                30                         922
# 4                                43                         886
# 5                                27                         922
# 6                                28                         953
# 7                                43                         617
# 8                                41                         907
# 9                                39                         987
# 10                               41                         656
# 11                               41                         698
# 12                               29                         894
# 13                               42                         676
# 14                               39                         670
# 15                               39                         737
# 16                               41                         740
# 17                               41                         722
# 18                               42                         729
# 19                               16                         677
#
#     silver [anish-making-sc-rods]  temperature [anish-making-sc-rods]   loss  \
# 0                             321                                  40  10.37
# 1                             339                                  32  10.89
# 2                             232                                  38  10.57
# 3                             292                                  38  13.30
# 4                             357                                  34  10.39
# 5                             292                                  38  10.28
# 6                             283                                  37  14.22
# 7                             334                                  39  10.24
# 8                             317                                  35  10.48
# 9                             230                                  36  11.40
# 10                            332                                  40  10.21
# 11                            326                                  39   9.96
# 12                            343                                  38  10.08
# 13                            314                                  39  10.22
# 14                            339                                  38  10.36
# 15                            340                                  38  10.25
# 16                            323                                  39  10.25
# 17                            321                                  39  10.28
# 18                            327                                  39  10.26
# 19                            300                                  26  10.92
#
#     [aucl]/[ag]  [hcl]/[aucl]  [aa]/[aucl]
# 0      1.557632         188.6         9.40
# 1      1.474926         199.4         6.30
# 2      2.155172         175.6         8.76
# 3      1.712329         184.4         3.60
# 4      1.400560         177.2         9.54
# 5      1.712329         184.4         7.82
# 6      1.766784         190.6         7.42
# 7      1.497006         123.4         9.60
# 8      1.577287         181.4         9.80
# 9      2.173913         197.4         9.60
# 10     1.506024         131.2         9.82
# 11     1.533742         139.6         9.64
# 12     1.457726         178.8         8.98
# 13     1.592357         135.2         9.46
# 14     1.474926         134.0         9.78
# 15     1.470588         147.4         9.94
# 16     1.547988         148.0         9.92
# 17     1.557632         144.4         9.72
# 18     1.529052         145.8         9.90
# 19     1.666667         135.4         9.62

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-23-sc-aunr-2/analysis-table/iterations.csv')

# Create a figure with three subplots
fig, axs = plt.subplots(nrows=6, sharex=True, figsize=(8, 6))

# Plot the first column against the second column in the first subplot
axs[0].plot(df.iloc[:, 0], df.iloc[:, 6])
axs[0].set_ylabel('Loss')

# Plot the first column against the third column in the second subplot
axs[1].plot(df.iloc[:, 0], df.iloc[:, 7])
axs[1].set_ylabel('[Au]/[Ag]')

# Plot the first column against the fourth column in the third subplot
axs[2].plot(df.iloc[:, 0], df.iloc[:, 8])
axs[2].set_ylabel('[HCl]/[Au]')

# Plot the first column against the fourth column in the fourth subplot
axs[3].plot(df.iloc[:, 0], df.iloc[:, 9])
axs[3].set_ylabel('[AA]/[Au]')

# Plot the first column against the fourth column in the fourth subplot
axs[4].plot(df.iloc[:, 0], df.iloc[:, 2])
axs[4].set_ylabel('Seed')

# Plot the first column against the fourth column in the fourth subplot
axs[5].plot(df.iloc[:, 0], df.iloc[:, 5])
axs[5].set_ylabel('Temp.')
axs[5].set_xlabel('Iteration')

# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.4)

# Show the plot
plt.show()

# %% [markdown]
# # Plotting volumes explored in reactions

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-23-sc-aunr-2/analysis-table/iterations.csv')

# Create a figure with three subplots
fig, axs = plt.subplots(nrows=5, sharex=True, figsize=(8, 6))

# Plot the first column against the second column in the first subplot
axs[0].plot(df.iloc[:, 0], df.iloc[:, 1])
axs[0].set_ylabel('V(AA)')
axs[0].set_ylim(10,500)

# Plot the first column against the third column in the second subplot
axs[1].plot(df.iloc[:, 0], df.iloc[:, 2])
axs[1].set_ylabel('Seeds')
axs[1].set_ylim(10,50)

# Plot the first column against the fourth column in the third subplot
axs[2].plot(df.iloc[:, 0], df.iloc[:, 3])
axs[2].set_ylabel('V(HCl)')
axs[2].set_ylim(100,1000)

# Plot the first column against the fourth column in the fourth subplot
axs[3].plot(df.iloc[:, 0], df.iloc[:, 4])
axs[3].set_ylabel('V(Ag)')
axs[3].set_ylim(100,400)

# Plot the first column against the fifth column in the fourth subplot
axs[4].plot(df.iloc[:, 0], df.iloc[:, 5])
axs[4].set_ylabel('Temp')
axs[4].set_ylim(25,40)
axs[4].set_xlabel('Iteration')

# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.4)

# Show the plot
plt.show()
