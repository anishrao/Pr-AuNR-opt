# %%
# Import all the necessary functions

import glob
import os, time
import itertools
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from cycler import cycler
from datetime import datetime, timedelta

from scipy.stats import norm
from scipy.optimize import curve_fit #we could import more, but this is what we need
from scipy.stats import linregress

# %matplotlib inline

# %%
df_obj = pd.read_csv('rev-obj.csv', header=None)
df_1 = pd.read_csv('exp1.csv', header=None)

# %%
df_obj
# Out:
#         0      1
# 0    1100  0.006
# 1    1099  0.006
# 2    1098  0.006
# 3    1097  0.006
# 4    1096  0.006
# ..    ...    ...
# 696   404  0.073
# 697   403  0.073
# 698   402  0.073
# 699   401  0.073
# 700   400  0.073
#
# [701 rows x 2 columns]

# %% [markdown]
# # Experiment 1

# %%
y_exp1 = df_1[1]
norm_y_exp1 = (y_exp1 - y_exp1.min())/(y_exp1.max()-y_exp1.min())

max_norm_dist_1 = np.linalg.norm(df_obj[1] - norm_y_exp1)
max_norm_dist_1 = round(max_norm_dist_1, 2)
print('loss: ',max_norm_dist_1)

plt.plot(df_obj[0], norm_y_exp1, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  12.2

# %% [markdown]
# # Experiment 2

# %%
df_2 = pd.read_csv('exp2.csv', header=None)

y_exp2 = df_2[1]
norm_y_exp2 = (y_exp2 - y_exp2.min())/(y_exp2.max()-y_exp2.min())

max_norm_dist_2 = np.linalg.norm(df_obj[1] - norm_y_exp2)
max_norm_dist_2 = round(max_norm_dist_2, 2)
print('loss: ',max_norm_dist_2)

plt.plot(df_obj[0], norm_y_exp2, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  11.98

# %% [markdown]
# # Experiment 3

# %%
df_3 = pd.read_csv('exp3.csv', header=None)

y_exp3 = df_3[1]
norm_y_exp3 = (y_exp3 - y_exp3.min())/(y_exp3.max()-y_exp3.min())

max_norm_dist_3 = np.linalg.norm(df_obj[1] - norm_y_exp3)
max_norm_dist_3 = round(max_norm_dist_3, 2)
print('loss: ',max_norm_dist_3)

plt.plot(df_obj[0], norm_y_exp3, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  10.38

# %% [markdown]
# # Experiment 4

# %%
df_4 = pd.read_csv('exp4.csv', header=None)

y_exp4 = df_4[1]
norm_y_exp4 = (y_exp4 - y_exp4.min())/(y_exp4.max()-y_exp4.min())

max_norm_dist_4 = np.linalg.norm(df_obj[1] - norm_y_exp4)
max_norm_dist_4 = round(max_norm_dist_4, 2)
print('loss: ',max_norm_dist_4)

plt.plot(df_obj[0], norm_y_exp4, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  8.46

# %% [markdown]
# # Experiment 5

# %%
df_5 = pd.read_csv('exp5.csv', header=None)

y_exp5 = df_5[1]
norm_y_exp5 = (y_exp5 - y_exp5.min())/(y_exp5.max()-y_exp5.min())

max_norm_dist_5 = np.linalg.norm(df_obj[1] - norm_y_exp5)
max_norm_dist_5 = round(max_norm_dist_5, 2)
print('loss: ',max_norm_dist_5)

plt.plot(df_obj[0], norm_y_exp5, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  10.6

# %% [markdown]
# # Experiment 6

# %%
df_6 = pd.read_csv('exp6.csv', header=None)

y_exp6 = df_6[1]
norm_y_exp6 = (y_exp6 - y_exp6.min())/(y_exp6.max()-y_exp6.min())

max_norm_dist_6 = np.linalg.norm(df_obj[1] - norm_y_exp6)
max_norm_dist_6 = round(max_norm_dist_6, 2)
print('loss: ',max_norm_dist_6)

plt.plot(df_obj[0], norm_y_exp6, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  11.34

# %% [markdown]
# # Experiment 7

# %%
df_7 = pd.read_csv('exp7.csv', header=None)

y_exp7 = df_7[1]
norm_y_exp7 = (y_exp7 - y_exp7.min())/(y_exp7.max()-y_exp7.min())

max_norm_dist_7 = np.linalg.norm(df_obj[1] - norm_y_exp7)
max_norm_dist_7 = round(max_norm_dist_7, 2)
print('loss: ',max_norm_dist_7)

plt.plot(df_obj[0], norm_y_exp7, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  9.95

# %% [markdown]
# # Experiment 8

# %%
df_8 = pd.read_csv('exp8.csv', header=None)

y_exp8 = df_8[1]
norm_y_exp8 = (y_exp8 - y_exp8.min())/(y_exp8.max()-y_exp8.min())

max_norm_dist_8 = np.linalg.norm(df_obj[1] - norm_y_exp8)
max_norm_dist_8 = round(max_norm_dist_8, 2)
print('loss: ',max_norm_dist_8)

plt.plot(df_obj[0], norm_y_exp8, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  10.82

# %% [markdown]
# # Experiment 9

# %%
df_9 = pd.read_csv('exp9.csv', header=None)

y_exp9 = df_9[1]
norm_y_exp9 = (y_exp9 - y_exp9.min())/(y_exp9.max()-y_exp9.min())

max_norm_dist_9 = np.linalg.norm(df_obj[1] - norm_y_exp9)
max_norm_dist_9 = round(max_norm_dist_9, 2)
print('loss: ',max_norm_dist_9)

plt.plot(df_obj[0], norm_y_exp9, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  7.69

# %% [markdown]
# # Experiment 10

# %%
df_10 = pd.read_csv('exp10.csv', header=None)

y_exp10 = df_10[1]
norm_y_exp10 = (y_exp10 - y_exp10.min())/(y_exp10.max()-y_exp10.min())

max_norm_dist_10 = np.linalg.norm(df_obj[1] - norm_y_exp10)
max_norm_dist_10 = round(max_norm_dist_10, 2)
print('loss: ',max_norm_dist_10)

plt.plot(df_obj[0], norm_y_exp10, 'r', label = 'Experiment')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  6.96

# %%
df_11 = pd.read_csv('exp11.csv', header=None)

y_exp11 = df_11[1]
norm_y_exp11 = (y_exp11 - y_exp11.min())/(y_exp11.max()-y_exp11.min())

max_norm_dist_11 = np.linalg.norm(df_obj[1] - norm_y_exp11)
max_norm_dist_11 = round(max_norm_dist_11, 2)
print('loss: ',max_norm_dist_11)

plt.plot(df_obj[0], norm_y_exp11, 'r', label = 'Experiment 11')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  7.81

# %%
df_12 = pd.read_csv('exp12.csv', header=None)

y_exp12 = df_12[1]
norm_y_exp12 = (y_exp12 - y_exp12.min())/(y_exp12.max()-y_exp12.min())

max_norm_dist_12 = np.linalg.norm(df_obj[1] - norm_y_exp12)
max_norm_dist_12 = round(max_norm_dist_12, 2)
print('loss: ',max_norm_dist_12)

plt.plot(df_obj[0], norm_y_exp12, 'r', label = 'Experiment 12')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  6.98

# %%
df_13 = pd.read_csv('exp13.csv', header=None)

y_exp13 = df_13[1]
norm_y_exp13 = (y_exp13 - y_exp13.min())/(y_exp13.max()-y_exp13.min())

max_norm_dist_13 = np.linalg.norm(df_obj[1] - norm_y_exp13)
max_norm_dist_13 = round(max_norm_dist_13, 2)
print('loss: ',max_norm_dist_13)

plt.plot(df_obj[0], norm_y_exp13, 'r', label = 'Experiment 13')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  6.94

# %%
df_14 = pd.read_csv('exp14.csv', header=None)

y_exp14 = df_14[1]
norm_y_exp14 = (y_exp14 - y_exp14.min())/(y_exp14.max()-y_exp14.min())

max_norm_dist_14 = np.linalg.norm(df_obj[1] - norm_y_exp14)
max_norm_dist_14 = round(max_norm_dist_14, 2)
print('loss: ',max_norm_dist_14)

plt.plot(df_obj[0], norm_y_exp14, 'r', label = 'Experiment 14')
plt.plot(df_obj[0], df_obj[1], 'k', label = 'Objective')
plt.xlim(400,1100)
plt.ylim(0,1.05)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Norm. Extinction')
plt.legend()
# Out:
# loss:  7.57
