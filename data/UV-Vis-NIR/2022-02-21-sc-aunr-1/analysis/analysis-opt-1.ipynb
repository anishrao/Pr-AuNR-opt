# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

# %%
df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-21-sc-aunr-1/analysis-table/iterations.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-b38f9dd9e60c> in <module>
# ----> 1 df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-21-sc-aunr-1/analysis-table/iterations.csv')
#       2 df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-21-sc-aunr-1/analysis-table/iterations.csv'

# %%
df.columns
# Out:
# Index(['Iteration #', 'Au seeds [Anish]', 'HCl (uL) [Anish]',
#        'ascorbic acid (uL) [Anish]', 'silver (uL) [Anish]',
#        'temperature [Anish]', 'loss parameter', '[aucl]/[ag]', '[hcl]/[aucl]',
#        '[aa]/[aucl]'],
#       dtype='object')

# %%
d = df[['Iteration #', 'Au seeds [Anish]', 'HCl (uL) [Anish]', 'ascorbic acid (uL) [Anish]', 'silver (uL) [Anish]','temperature [Anish]', 'loss parameter']]

parallel_coordinates(d, 'loss parameter')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e9483078f27c> in <module>
# ----> 1 d = df[['Iteration #', 'Au seeds [Anish]', 'HCl (uL) [Anish]', 'ascorbic acid (uL) [Anish]', 'silver (uL) [Anish]','temperature [Anish]', 'loss parameter']]
#       2
#       3 parallel_coordinates(d, 'loss parameter')
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

fig = px.parallel_coordinates(d, color="loss parameter",
                              dimensions=[('Au seeds [Anish]'), 'HCl (uL) [Anish]', 'ascorbic acid (uL) [Anish]', 'silver (uL) [Anish]','temperature [Anish]', 'loss parameter'])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-53b54a0bcb66> in <module>
#       3 import pandas as pd
#       4
# ----> 5 fig = px.parallel_coordinates(d, color="loss parameter",
#       6                               dimensions=[('Au seeds [Anish]'), 'HCl (uL) [Anish]', 'ascorbic acid (uL) [Anish]', 'silver (uL) [Anish]','temperature [Anish]', 'loss parameter'])
#       7 fig.show()
#
# NameError: name 'd' is not defined

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-21-sc-aunr-1/analysis-table/iterations.csv')

# Create a figure with three subplots
fig, axs = plt.subplots(nrows=6, sharex=True, figsize=(8, 6))

# Plot the first column against the second column in the first subplot
axs[0].plot(df.iloc[:, 0], df.iloc[:, 6])
axs[0].set_ylabel('Loss')

# Plot the first column against the third column in the second subplot
axs[1].plot(df.iloc[:, 0], df.iloc[:, 7])
axs[1].set_ylabel('[Au]/[Ag]')

# Plot the first column against the fourth column in the third subplot
axs[2].plot(df.iloc[:, 0], df.iloc[:, 8])
axs[2].set_ylabel('[HCl]/[Au]')

# Plot the first column against the fourth column in the fourth subplot
axs[3].plot(df.iloc[:, 0], df.iloc[:, 9])
axs[3].set_ylabel('[AA]/[Au]')

# Plot the first column against the fifth column in the fourth subplot
axs[4].plot(df.iloc[:, 0], df.iloc[:, 1])
axs[4].set_ylabel('Seed')

# Plot the first column against the sixth column in the fourth subplot
axs[5].plot(df.iloc[:, 0], df.iloc[:, 5])
axs[5].set_ylabel('Temp.')
axs[5].set_xlabel('Iteration')


# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.4)

# Show the plot
plt.show()

# %% [markdown]
# # Plotting volumes explored in the reactions

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-21-sc-aunr-1/analysis-table/iterations.csv')

# Create a figure with three subplots
fig, axs = plt.subplots(nrows=5, sharex=True, figsize=(8, 6))

# Plot the first column against the second column in the first subplot
axs[0].plot(df.iloc[:, 0], df.iloc[:, 1])
axs[0].set_ylabel('Seeds')
axs[0].set_ylim(10,50)

# Plot the first column against the third column in the second subplot
axs[1].plot(df.iloc[:, 0], df.iloc[:, 2])
axs[1].set_ylabel('V(HCl)')
axs[1].set_ylim(100,1000)

# Plot the first column against the fourth column in the third subplot
axs[2].plot(df.iloc[:, 0], df.iloc[:, 3])
axs[2].set_ylabel('V(AA)')
axs[2].set_ylim(100,500)

# Plot the first column against the fourth column in the fourth subplot
axs[3].plot(df.iloc[:, 0], df.iloc[:, 4])
axs[3].set_ylabel('V(Ag)')
axs[3].set_ylim(100,400)

# Plot the first column against the fifth column in the fourth subplot
axs[4].plot(df.iloc[:, 0], df.iloc[:, 5])
axs[4].set_ylabel('Temp')
axs[4].set_ylim(25,40)
axs[4].set_xlabel('Iteration')

# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.4)

# Show the plot
plt.show()
