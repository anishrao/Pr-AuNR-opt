# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-21-sc-aunr-1/analysis-table/iterations.csv')
df
# Out:
#     Iteration #  Au seeds [Anish]  HCl (uL) [Anish]  \
# 0             1              49.4               558
# 1             2              10.2               867
# 2             3              35.0               431
# 3             4              36.0               146
# 4             5              22.0               186
# 5             6              43.0               337
# 6             7              26.0               249
# 7             8              18.0               152
# 8             9              38.0               166
# 9            10              40.0               203
# 10           11              39.0               232
# 11           12              40.0               234
# 12           13              34.0               208
# 13           14              25.0               443
# 14           15              34.0               193
# 15           16              33.0               234
# 16           17              34.0               236
#
#     ascorbic acid (uL) [Anish]  silver (uL) [Anish]  temperature [Anish]  \
# 0                          235                  183                   38
# 1                          477                  113                   34
# 2                          359                  256                   36
# 3                          407                  137                   37
# 4                          395                  153                   34
# 5                          188                  123                   38
# 6                          222                  229                   36
# 7                          217                  210                   38
# 8                          416                  128                   37
# 9                          435                  117                   36
# 10                         446                  127                   35
# 11                         444                  106                   35
# 12                         476                  108                   35
# 13                         485                  108                   38
# 14                         492                  122                   36
# 15                         478                  104                   35
# 16                         477                  118                   34
#
#     loss parameter  [aucl]/[ag]  [hcl]/[aucl]  [aa]/[aucl]
# 0            12.20     2.732240         111.6         4.70
# 1            11.98     4.424779         173.4         9.54
# 2            10.38     1.953125          86.2         7.18
# 3             8.46     3.649635          29.2         8.14
# 4            10.60     3.267974          37.2         7.90
# 5            11.34     4.065041          67.4         3.76
# 6             9.95     2.183406          49.8         4.44
# 7            10.82     2.380952          30.4         4.34
# 8             7.69     3.906250          33.2         8.32
# 9             6.96     4.273504          40.6         8.70
# 10            7.81     3.937008          46.4         8.92
# 11            6.98     4.716981          46.8         8.88
# 12            6.94     4.629630          41.6         9.52
# 13            7.57     4.629630          88.6         9.70
# 14            7.18     4.098361          38.6         9.84
# 15            6.94     4.807692          46.8         9.56
# 16            6.76     4.237288          47.2         9.54

# %%
fig, (ax1, ax2, ax3)  = plt.subplots(1, 3, sharey= True)

ax1.scatter(df['[aucl]/[ag]'], df['loss parameter'], label='Au/ Ag')
ax2.scatter(df['[hcl]/[aucl]'], df['loss parameter'], label='HCl/Au')
ax3.scatter(df['[aa]/[aucl]'], df['loss parameter'], label='AA/Au')
ax1.axhline(y = 4.43)
ax2.axhline(y = 4.43)
ax3.axhline(y = 4.43)
plt.ylim(0,13)
# Out:
# (0.0, 13.0)

# %%
# Read the CSV file into a Pandas DataFrame
df = pd.read_csv('/home/anish/Desktop/01-cfm/Pr004_chemOS/Data/2022-02-21-sc-aunr-1/analysis-table/iterations.csv')

# Create a figure with three subplots
fig, axs = plt.subplots(nrows=6, sharex=True, figsize=(8, 6))

# Plot the first column against the second column in the first subplot
axs[0].plot(df.iloc[:, 0], df.iloc[:, 6])
axs[0].set_ylabel('Loss')

# Plot the first column against the third column in the second subplot
axs[1].plot(df.iloc[:, 0], df.iloc[:, 7])
axs[1].set_ylabel('[Au]/[Ag]')

# Plot the first column against the fourth column in the third subplot
axs[2].plot(df.iloc[:, 0], df.iloc[:, 8])
axs[2].set_ylabel('[HCl]/[Au]')

# Plot the first column against the fourth column in the fourth subplot
axs[3].plot(df.iloc[:, 0], df.iloc[:, 9])
axs[3].set_ylabel('[AA]/[Au]')

# Plot the first column against the fifth column in the fourth subplot
axs[4].plot(df.iloc[:, 0], df.iloc[:, 1])
axs[4].set_ylabel('Seed')

# Plot the first column against the sixth column in the fourth subplot
axs[5].plot(df.iloc[:, 0], df.iloc[:, 5])
axs[5].set_ylabel('Temp.')
axs[5].set_xlabel('Iteration')

# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.4)

# Show the plot
plt.show()
