# %%
# check installed version (must be >3.0)
import pycaret
import pandas as pd
pycaret.__version__
# Out:
# '3.0.2'

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from yellowbrick.regressor import ResidualsPlot

# %%
data = pd.read_csv('dataset_exp1.csv')
data
# Out:
#     Au seeds [Anish]  HCl (uL) [Anish]  ascorbic acid (uL) [Anish]  \
# 0               24.0               850                         215
# 1               24.0               712                         167
# 2               24.0               269                         288
# 3               24.0               281                         484
# 4               24.0               488                         391
# 5               24.0               716                         238
# 6               24.0               330                         322
# 7               24.0               300                         100
# 8               24.0              1000                         335
# 9               24.0               323                         350
# 10              24.0               286                         342
# 11              49.4               558                         235
# 12              10.2               867                         477
# 13              35.0               431                         359
# 14              36.0               146                         407
# 15              22.0               186                         395
# 16              43.0               337                         188
# 17              26.0               249                         222
# 18              18.0               152                         217
# 19              38.0               166                         416
# 20              40.0               203                         435
# 21              39.0               232                         446
# 22              40.0               234                         444
# 23              34.0               208                         476
# 24              25.0               443                         485
# 25              34.0               193                         492
# 26              33.0               234                         478
# 27              34.0               236                         477
# 28              32.0               207                         480
# 29              31.0               236                         464
# 30              30.0               229                         490
# 31              47.0               764                         470
# 32              45.0               870                         477
# 33              37.0               470                         468
# 34              47.0               929                         499
# 35              31.0               648                         481
# 36              38.0               428                         453
# 37              48.0               815                         329
# 38              36.0               446                         463
# 39              38.0               503                         452
# 40              39.0               527                         460
# 41              49.0               748                         395
# 42              36.0               542                         434
# 43              36.0               702                         481
# 44              36.0               516                         466
# 45              40.0               555                         482
# 46              37.0               512                         468
# 47              11.0               403                         245
# 48              39.0               506                         469
# 49              30.0               207                         306
# 50              26.0               450                         111
#
#     silver (uL) [Anish]  temperature [Anish]  loss parameter
# 0                   195                   27           12.45
# 1                   440                   27           10.19
# 2                   335                   27           11.11
# 3                   380                   27           11.00
# 4                   126                   27            8.67
# 5                   407                   27           10.08
# 6                   159                   27           10.91
# 7                   183                   27           11.44
# 8                   500                   27           10.28
# 9                   100                   27            6.66
# 10                  100                   27            6.74
# 11                  183                   38           12.20
# 12                  113                   34           11.98
# 13                  256                   36           10.38
# 14                  137                   37            8.46
# 15                  153                   34           10.60
# 16                  123                   38           11.34
# 17                  229                   36            9.95
# 18                  210                   38           10.82
# 19                  128                   37            7.69
# 20                  117                   36            6.96
# 21                  127                   35            7.81
# 22                  106                   35            6.98
# 23                  108                   35            6.94
# 24                  108                   38            7.57
# 25                  122                   36            7.18
# 26                  104                   35            6.94
# 27                  118                   34            6.76
# 28                  104                   34            6.63
# 29                  100                   34            6.65
# 30                  100                   33            7.02
# 31                  299                   40            9.83
# 32                  352                   34            9.81
# 33                  104                   38            7.84
# 34                  199                   37           10.10
# 35                  162                   39           10.09
# 36                  112                   38            8.76
# 37                  175                   36           10.65
# 38                  112                   38            8.95
# 39                  100                   39            7.58
# 40                  100                   39            7.83
# 41                  103                   40           11.95
# 42                  101                   39            8.11
# 43                  139                   26           12.40
# 44                  112                   40           10.38
# 45                  103                   37            8.26
# 46                  101                   40            8.02
# 47                  174                   38           10.38
# 48                  102                   39            8.46
# 49                  280                   30           10.84
# 50                  124                   26           13.04

# %%
# import pycaret regression and init setup
from pycaret.regression import *

s = setup(data, target = 'loss parameter', session_id = 123, normalize=True)
# Out:
# <style type="text/css">
# #T_ffa38_row8_col1, #T_ffa38_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ffa38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffa38_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ffa38_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffa38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffa38_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ffa38_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ffa38_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ffa38_row1_col1" class="data row1 col1" >loss parameter</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ffa38_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ffa38_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ffa38_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ffa38_row3_col1" class="data row3 col1" >(51, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ffa38_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ffa38_row4_col1" class="data row4 col1" >(51, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ffa38_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ffa38_row5_col1" class="data row5 col1" >(35, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ffa38_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ffa38_row6_col1" class="data row6 col1" >(16, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ffa38_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ffa38_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ffa38_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_ffa38_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ffa38_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_ffa38_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ffa38_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_ffa38_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ffa38_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_ffa38_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ffa38_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_ffa38_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ffa38_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_ffa38_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ffa38_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_ffa38_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ffa38_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_ffa38_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ffa38_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_ffa38_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ffa38_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_ffa38_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ffa38_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_ffa38_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ffa38_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_ffa38_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ffa38_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ffa38_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_ffa38_row20_col1" class="data row20 col1" >82a4</td>
#     </tr>
#   </tbody>
# </table>

# %%
# import RegressionExperiment and init the class
from pycaret.regression import RegressionExperiment
exp = RegressionExperiment()

# %%
# compare baseline models
best = compare_models(fold=10)
# Out:
# <style type="text/css">
# #T_3012e th {
#   text-align: left;
# }
# #T_3012e_row0_col0, #T_3012e_row0_col1, #T_3012e_row0_col2, #T_3012e_row0_col3, #T_3012e_row0_col5, #T_3012e_row0_col6, #T_3012e_row1_col0, #T_3012e_row1_col2, #T_3012e_row1_col4, #T_3012e_row2_col0, #T_3012e_row2_col1, #T_3012e_row2_col3, #T_3012e_row2_col4, #T_3012e_row2_col5, #T_3012e_row2_col6, #T_3012e_row3_col0, #T_3012e_row3_col1, #T_3012e_row3_col2, #T_3012e_row3_col3, #T_3012e_row3_col4, #T_3012e_row3_col5, #T_3012e_row3_col6, #T_3012e_row4_col0, #T_3012e_row4_col1, #T_3012e_row4_col2, #T_3012e_row4_col3, #T_3012e_row4_col4, #T_3012e_row4_col5, #T_3012e_row4_col6, #T_3012e_row5_col0, #T_3012e_row5_col1, #T_3012e_row5_col2, #T_3012e_row5_col3, #T_3012e_row5_col4, #T_3012e_row5_col5, #T_3012e_row5_col6, #T_3012e_row6_col0, #T_3012e_row6_col1, #T_3012e_row6_col2, #T_3012e_row6_col3, #T_3012e_row6_col4, #T_3012e_row6_col5, #T_3012e_row6_col6, #T_3012e_row7_col0, #T_3012e_row7_col1, #T_3012e_row7_col2, #T_3012e_row7_col3, #T_3012e_row7_col4, #T_3012e_row7_col5, #T_3012e_row7_col6, #T_3012e_row8_col0, #T_3012e_row8_col1, #T_3012e_row8_col2, #T_3012e_row8_col3, #T_3012e_row8_col4, #T_3012e_row8_col5, #T_3012e_row8_col6, #T_3012e_row9_col0, #T_3012e_row9_col1, #T_3012e_row9_col2, #T_3012e_row9_col3, #T_3012e_row9_col4, #T_3012e_row9_col5, #T_3012e_row9_col6, #T_3012e_row10_col0, #T_3012e_row10_col1, #T_3012e_row10_col2, #T_3012e_row10_col3, #T_3012e_row10_col4, #T_3012e_row10_col5, #T_3012e_row10_col6, #T_3012e_row11_col0, #T_3012e_row11_col1, #T_3012e_row11_col2, #T_3012e_row11_col3, #T_3012e_row11_col4, #T_3012e_row11_col5, #T_3012e_row11_col6, #T_3012e_row12_col0, #T_3012e_row12_col1, #T_3012e_row12_col2, #T_3012e_row12_col3, #T_3012e_row12_col4, #T_3012e_row12_col5, #T_3012e_row12_col6, #T_3012e_row13_col0, #T_3012e_row13_col1, #T_3012e_row13_col2, #T_3012e_row13_col3, #T_3012e_row13_col4, #T_3012e_row13_col5, #T_3012e_row13_col6, #T_3012e_row14_col0, #T_3012e_row14_col1, #T_3012e_row14_col2, #T_3012e_row14_col3, #T_3012e_row14_col4, #T_3012e_row14_col5, #T_3012e_row14_col6, #T_3012e_row15_col0, #T_3012e_row15_col1, #T_3012e_row15_col2, #T_3012e_row15_col3, #T_3012e_row15_col4, #T_3012e_row15_col5, #T_3012e_row15_col6, #T_3012e_row16_col0, #T_3012e_row16_col1, #T_3012e_row16_col2, #T_3012e_row16_col3, #T_3012e_row16_col4, #T_3012e_row16_col5, #T_3012e_row16_col6, #T_3012e_row17_col0, #T_3012e_row17_col1, #T_3012e_row17_col2, #T_3012e_row17_col3, #T_3012e_row17_col4, #T_3012e_row17_col5, #T_3012e_row17_col6, #T_3012e_row18_col0, #T_3012e_row18_col1, #T_3012e_row18_col2, #T_3012e_row18_col3, #T_3012e_row18_col4, #T_3012e_row18_col5, #T_3012e_row18_col6, #T_3012e_row19_col0, #T_3012e_row19_col1, #T_3012e_row19_col2, #T_3012e_row19_col3, #T_3012e_row19_col4, #T_3012e_row19_col5, #T_3012e_row19_col6 {
#   text-align: left;
# }
# #T_3012e_row0_col4, #T_3012e_row1_col1, #T_3012e_row1_col3, #T_3012e_row1_col5, #T_3012e_row1_col6, #T_3012e_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3012e_row0_col7, #T_3012e_row1_col7, #T_3012e_row2_col7, #T_3012e_row3_col7, #T_3012e_row4_col7, #T_3012e_row5_col7, #T_3012e_row6_col7, #T_3012e_row7_col7, #T_3012e_row8_col7, #T_3012e_row9_col7, #T_3012e_row10_col7, #T_3012e_row11_col7, #T_3012e_row12_col7, #T_3012e_row14_col7, #T_3012e_row15_col7, #T_3012e_row17_col7, #T_3012e_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3012e_row13_col7, #T_3012e_row16_col7, #T_3012e_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3012e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3012e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3012e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3012e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3012e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3012e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3012e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3012e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3012e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3012e_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_3012e_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_3012e_row0_col1" class="data row0 col1" >0.8049</td>
#       <td id="T_3012e_row0_col2" class="data row0 col2" >1.3847</td>
#       <td id="T_3012e_row0_col3" class="data row0 col3" >1.0077</td>
#       <td id="T_3012e_row0_col4" class="data row0 col4" >0.0280</td>
#       <td id="T_3012e_row0_col5" class="data row0 col5" >0.0990</td>
#       <td id="T_3012e_row0_col6" class="data row0 col6" >0.0876</td>
#       <td id="T_3012e_row0_col7" class="data row0 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_3012e_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_3012e_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_3012e_row1_col1" class="data row1 col1" >0.7111</td>
#       <td id="T_3012e_row1_col2" class="data row1 col2" >1.2485</td>
#       <td id="T_3012e_row1_col3" class="data row1 col3" >0.9479</td>
#       <td id="T_3012e_row1_col4" class="data row1 col4" >0.0250</td>
#       <td id="T_3012e_row1_col5" class="data row1 col5" >0.0895</td>
#       <td id="T_3012e_row1_col6" class="data row1 col6" >0.0764</td>
#       <td id="T_3012e_row1_col7" class="data row1 col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_3012e_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_3012e_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_3012e_row2_col1" class="data row2 col1" >0.7826</td>
#       <td id="T_3012e_row2_col2" class="data row2 col2" >1.2190</td>
#       <td id="T_3012e_row2_col3" class="data row2 col3" >0.9545</td>
#       <td id="T_3012e_row2_col4" class="data row2 col4" >-0.2885</td>
#       <td id="T_3012e_row2_col5" class="data row2 col5" >0.0934</td>
#       <td id="T_3012e_row2_col6" class="data row2 col6" >0.0853</td>
#       <td id="T_3012e_row2_col7" class="data row2 col7" >0.3250</td>
#     </tr>
#     <tr>
#       <th id="T_3012e_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_3012e_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#       <td id="T_3012e_row3_col1" class="data row3 col1" >0.8740</td>
#       <td id="T_3012e_row3_col2" class="data row3 col2" >1.7554</td>
#       <td id="T_3012e_row3_col3" class="data row3 col3" >1.0992</td>
#       <td id="T_3012e_row3_col4" class="data row3 col4" >-0.2916</td>
#       <td id="T_3012e_row3_col5" class="data row3 col5" >0.1062</td>
#       <td id="T_3012e_row3_col6" class="data row3 col6" >0.0929</td>
#       <td id="T_3012e_row3_col7" class="data row3 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_3012e_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_3012e_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_3012e_row4_col1" class="data row4 col1" >0.8338</td>
#       <td id="T_3012e_row4_col2" class="data row4 col2" >1.5345</td>
#       <td id="T_3012e_row4_col3" class="data row4 col3" >1.0189</td>
#       <td id="T_3012e_row4_col4" class="data row4 col4" >-0.5086</td>
#       <td id="T_3012e_row4_col5" class="data row4 col5" >0.0998</td>
#       <td id="T_3012e_row4_col6" class="data row4 col6" >0.0880</td>
#       <td id="T_3012e_row4_col7" class="data row4 col7" >0.0390</td>
#     </tr>
#     <tr>
#       <th id="T_3012e_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_3012e_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_3012e_row5_col1" class="data row5 col1" >0.8777</td>
#       <td id="T_3012e_row5_col2" class="data row5 col2" >1.6169</td>
#       <td id="T_3012e_row5_col3" class="data row5 col3" >1.1114</td
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %%
plot_model(best)

# %%
plot_model(best, 'error')

# %%
plot_model(best, plot='feature')

# %%
# predict on test set
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cb73e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb73e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cb73e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cb73e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cb73e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cb73e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cb73e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cb73e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb73e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb73e_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_cb73e_row0_col1" class="data row0 col1" >0.8294</td>
#       <td id="T_cb73e_row0_col2" class="data row0 col2" >1.8059</td>
#       <td id="T_cb73e_row0_col3" class="data row0 col3" >1.3438</td>
#       <td id="T_cb73e_row0_col4" class="data row0 col4" >0.5366</td>
#       <td id="T_cb73e_row0_col5" class="data row0 col5" >0.1164</td>
#       <td id="T_cb73e_row0_col6" class="data row0 col6" >0.0745</td>
#     </tr>
#   </tbody>
# </table>

# %%
# show predictions df
holdout_pred.head()
# Out:
#     Au seeds [Anish]  HCl (uL) [Anish]  ascorbic acid (uL) [Anish]  \
# 29              31.0               236                         464
# 13              35.0               431                         359
# 47              11.0               403                         245
# 31              47.0               764                         470
# 10              24.0               286                         342
#
#     silver (uL) [Anish]  temperature [Anish]  loss parameter  prediction_label
# 29                  100                   34            6.65          6.945714
# 13                  256                   36           10.38         10.508571
# 47                  174                   38           10.38         10.586000
# 31                  299                   40            9.83         10.310000
# 10                  100                   27            6.74          6.927692

# %%
evaluate_model(best)

# %%
# interpret summary model
interpret_model(best, plot = 'summary')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_19267/515934483.py in <module>
#       1 # interpret summary model
# ----> 2 interpret_model(best, plot = 'summary')
#
# ~/.local/lib/python3.10/site-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# ~/.local/lib/python3.10/site-packages/pycaret/regression/functional.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1844     """
#    1845
# -> 1846     return _CURRENT_EXPERIMENT.interpret_model(
#    1847         estimator=estimator,
#    1848         plot=plot,
#
# ~/.local/lib/python3.10/site-packages/pycaret/regression/oop.py in interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2142         """
#    2143
# -> 2144         return super().interpret_model(
#    2145             estimator=estimator,
#    2146             plot=plot,
#
# ~/.local/lib/python3.10/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py in interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4054             model_id not in shap_models_ids
#    4055         ):
# -> 4056             raise TypeError(
#    4057                 f"This function only supports tree based models for binary classification: {', '.join(shap_models_ids)}."
#    4058             )
#
# TypeError: This function only supports tree based models for binary classification: et, dt, rf, xgboost, catboost, lightgbm.
